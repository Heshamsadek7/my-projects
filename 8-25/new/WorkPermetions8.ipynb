# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# تحميل البيانات
df = pd.read_csv('/home/hesham/NMG/8-25/new/work permations.csv', encoding='utf-8')

# %%
df.columns
# Out:
# Index(['الشهر', 'التاريخ', 'اليوم', 'إسم الشركة', 'المشرف التنفيزى ',
#        'نوع العمل', 'مواقف التصريح', 'ساعة الدخول ', 'ساعة الخروج',
#        'إجمالي عدد الساعات', 'الموقع', 'إجمالي ساعات العمل', 'المصدر', 'عمود1',
#        'مشرف السلامة', 'تقييم العملية', 'عمود2', 'عمود3', 'عمود4', 'عمود5',
#        'عمود6', 'عمود7', 'عمود8', 'عمود9', 'عمود10', 'Column1'],
#       dtype='object')

# %%
# لعرض عدد محدد من الأعمدة (مثلاً 50 عمود)
pd.set_option('display.max_columns', 26)
df.head(2)
# Out:
#       الشهر     التاريخ      اليوم        إسم الشركة المشرف التنفيزى   \
# 0  يوليو-25  01/07/2025  الثلاثاء   الشؤون الادارية        محمود عويس
# 1  يوليو-25  02/07/2025  الاربعاء   الشؤون الادارية        محمود عويس
#
#                 نوع العمل مواقف التصريح ساعة الدخول  ساعة الخروج  \
# 0  صيانة مبرد مياه الشرب       تم العمل     14:00:00    17:00:00
# 1  صيانة مبرد مياه الشرب       تم العمل     10:00:00    13:00:00
#
#   إجمالي عدد الساعات    الموقع إجمالي ساعات العمل  المصدر  عمود1 مشرف السلامة  \
# 0              0٫125  المطابع                   3     NaN    NaN   كريم مجدى
# 1              0٫125  المطابع                   3     NaN    NaN   كريم مجدى
#
#    تقييم العملية عمود2  عمود3  عمود4  عمود5  عمود6  عمود7  عمود8  عمود9  \
# 0              5   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1              5   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    عمود10  Column1
# 0     NaN      NaN
# 1     NaN      NaN

# %%
df=df[['الشهر', 'التاريخ', 'اليوم', 'إسم الشركة', 'المشرف التنفيزى ',
       'نوع العمل', 'مواقف التصريح', 'ساعة الدخول ', 'ساعة الخروج',
       #'إجمالي عدد الساعات',
       'الموقع', 'إجمالي ساعات العمل',
        # 'المصدر', 'عمود1',
       'مشرف السلامة', 
       #'تقييم العملية', 'عمود2', 'عمود3', 'عمود4', 'عمود5',
       #'عمود6', 'عمود7', 'عمود8', 'عمود9', 'عمود10',
       # 'Column1'
       ]]

# %%
df.columns
# Out:
# Index(['الشهر', 'التاريخ', 'اليوم', 'إسم الشركة', 'المشرف التنفيزى ',
#        'نوع العمل', 'مواقف التصريح', 'ساعة الدخول ', 'ساعة الخروج', 'الموقع',
#        'إجمالي ساعات العمل', 'مشرف السلامة'],
#       dtype='object')

# %%
df.head(2)
# Out:
#       الشهر     التاريخ      اليوم        إسم الشركة المشرف التنفيزى   \
# 0  يوليو-25  01/07/2025  الثلاثاء   الشؤون الادارية        محمود عويس
# 1  يوليو-25  02/07/2025  الاربعاء   الشؤون الادارية        محمود عويس
#
#                 نوع العمل مواقف التصريح ساعة الدخول  ساعة الخروج    الموقع  \
# 0  صيانة مبرد مياه الشرب       تم العمل     14:00:00    17:00:00  المطابع
# 1  صيانة مبرد مياه الشرب       تم العمل     10:00:00    13:00:00  المطابع
#
#   إجمالي ساعات العمل مشرف السلامة
# 0                  3   كريم مجدى
# 1                  3   كريم مجدى

# %%
# ترجمة أسماء الأعمدة
column_mapping ={'الشهر':'Month',
                'التاريخ':'Date',
                'اليوم':'Day',
                'إسم الشركة':'Company_Name',
                'المشرف التنفيزى ':'Executive_Supervisor',
                'نوع العمل':'Type of Work', 'مواقف التصريح':'Permit Position', 'ساعة الدخول ':'Hour_in', 'ساعة الخروج':'Hour_out',
                 'الموقع':'Location', 'إجمالي ساعات العمل':'Total Hours', 'مشرف السلامة':'Safety Supervisor'}

# %%
# Rename the columns
df = df.rename(columns=column_mapping)

# %%
df.columns
# Out:
# Index(['Month', 'Date', 'Day', 'Company_Name', 'Executive_Supervisor',
#        'Type of Work', 'Permit Position', 'Hour_in', 'Hour_out', 'Location',
#        'Total Hours', 'Safety Supervisor'],
#       dtype='object')

# %%
df.head(2)
# Out:
#       Month        Date        Day      Company_Name Executive_Supervisor  \
# 0  يوليو-25  01/07/2025  الثلاثاء   الشؤون الادارية            محمود عويس
# 1  يوليو-25  02/07/2025  الاربعاء   الشؤون الادارية            محمود عويس
#
#              Type of Work Permit Position   Hour_in  Hour_out  Location  \
# 0  صيانة مبرد مياه الشرب         تم العمل  14:00:00  17:00:00  المطابع
# 1  صيانة مبرد مياه الشرب         تم العمل  10:00:00  13:00:00  المطابع
#
#   Total Hours Safety Supervisor
# 0           3        كريم مجدى
# 1           3        كريم مجدى

# %%
# إزالة المسافات والفواصل إذا كانت موجودة
df['Total Hours'] = df['Total Hours'].str.replace('٫', '.', regex=False)


# ثم التحويل إلى numeric ثم float
df['Total Hours'] = df['Total Hours'].astype(float)

# %%
Location_Translation = {
    'المطابع ': 'Printing Presses',
    'المخزن القديم ': 'Old Warehouse', 
    'البرج': 'Tower',
    'المخزن الجديد ': 'New Warehouse',
    'الفجالة': 'Faggala',
    'دويتش ': 'Deutsch'
}

# %%
#ترجمة الشركات
company_translation_dict = {
    'الشؤون الادارية ': 'Administrative Affairs',
    'شركة الهدى ': 'Al-Huda Company',
    'شركة الامل للالمونتال': 'Al-Amal for Installation Company',
    'القطاع الهندسى ': 'Engineering Sector',
    'شركة اوزوريون ': 'Orion Company',
    'مقاول خارجي': 'External Contractor',
    'الشركة الالمانية ': 'German Company',
    'شركة شلاندر ': 'Schlender Company',
    'شركة وان كونكت': 'One Connect Company',
    'ادارة المخازن ': 'Warehouse Management',
    'شركة الدروى ': 'Al-Darawy Company',
    'شركة سكوير ': 'Square Company',
    'شركة البكرى ': 'Al-Bakry Company',
    'شركة الفرج': 'Al-Farag Company',
    'الشركة المصرية ': 'Egyptian Company',
    'شركة أطلس ': 'Atlas Company',
    'الهندسية لضواغط الهواء ': 'Engineering for Air Compressors',
    'شركة كايرو تريد ': 'Cairo Trade Company',
    'شركة الدسوقي': 'Al-Dessouky Company',
    'ادارة المتابعة والمراقبة ': 'Follow-up and Monitoring Management',
    'أوفيس مكس': 'Office Max',
    'شركة كيمكس': 'Chemex Company',
    'شركة GM': 'GM Company',
    'KUC  شركة ': 'KUC Company',
    'شركة فور تيك ': 'Four Tech Company',
    'شركة الكريم ': 'Al-Karim Company',
    'الشركة الوطنية ': 'National Company',
    'شركة جلوب ويل ': 'Globe Well Company',
    'شركة المتحدة': 'United Company',
    'شركة الاسكندرية': 'Alexandria Company',
    'الشئون الادارية': 'Administrative Affairs',
    'شركة الهدي ': 'Al-Hady Company'
}

# %%
Safety_Supervisor_Translation = {
    ' كريم مجدى ': 'Karim Magdy',
    'محمود عبد التواب  عبد الحميد': 'Mahmoud AbdelTawab',
    'على صلاح على حسين   ': 'Ali Salah',
    'محمد محمود عبد العال ': 'Mohamed Abdel Aal',
    'محمد السيد عبد التواب ': 'Mohamed El-Sayed',
    'احمد سعد طلبة ': 'Ahmed Saad',
    'احمد مرسى مرسى جبر ': 'Ahmed Morsy',
    'محمد موسى اسماعيل  ': 'Mohamed Moussa',
    'هانى لطفى الميلجي عبد الحميد': 'Hany Lotfy',
    'احمد محمود بكرى ': 'Ahmed Bakry',
    'محمود مصطفى سيد ': 'Mahmoud Mostafa',
    'علاء عنتر  محمد ': 'Alaa Antar'
}

# %%
# ترجمة الشهور
month_translation = {
    'يوليو-25': 'July-25',
    'أغسطس-25': 'August-25'
}

# %%
MY_colors=["#17CB44", "#E86262","#DAEE25","#19D4EC","#4D0909","#7DA7D6F4","#EC2727","#13A845","#1F0757","#C2DD82","#C73E8E","#088F30"]

# %%
df['Month']=df['Month'].replace(month_translation)
df['Safety Supervisor'] = df['Safety Supervisor'].replace(Safety_Supervisor_Translation)
df['Location']=df['Location'].replace(Location_Translation)
df['Company_Name']=df['Company_Name'].replace(company_translation_dict)

# %%
# فصل البيانات حسب الشهر
august_permations = df[df['Month'] == 'August-25']
july_permations = df[df['Month'] == 'July-25']

# %%
df.dtypes
# Out:
# Month                    object
# Date                     object
# Day                      object
# Company_Name             object
# Executive_Supervisor     object
# Type of Work             object
# Permit Position          object
# Hour_in                  object
# Hour_out                 object
# Location                 object
# Total Hours             float64
# Safety Supervisor        object
# dtype: object

# %%
df["Month"]=pd.to_datetime(df['Month'], errors='coerce')
df["Date"]=pd.to_datetime(df['Date'], errors='coerce')
df["Day"]=pd.to_datetime(df['Day'], errors='coerce')
df["Hour_in"]=pd.to_datetime(df['Hour_in'], errors='coerce')
df["Hour_out"]=pd.to_datetime(df['Hour_out'], errors='coerce')

# %%
df['Location'].value_counts()
# Out:
# Location
# Printing Presses    66
# Old Warehouse       55
# New Warehouse       27
# Tower               23
# Faggala             16
# Deutsch              4
# Name: count, dtype: int64

# %%
df.loc[df['Location'] != 'Deutsch'].groupby('Location')['Total Hours'].sum().sort_values(ascending=False)
# Out:
# Location
# Old Warehouse       241.50
# Printing Presses    217.30
# Tower               116.35
# New Warehouse        70.00
# Faggala              38.00
# Name: Total Hours, dtype: float64

# %%
result = df.loc[df['Location'] != 'Deutsch'].groupby(['Safety Supervisor', 'Location'])['Total Hours'].sum().unstack().fillna(0)
result.loc[result.sum(axis=1).sort_values(ascending=False).index]
# Out:
# Location            Faggala  New Warehouse  Old Warehouse  Printing Presses  \
# Safety Supervisor
# Mahmoud AbdelTawab      0.0            6.0          152.0               9.0
# Mohamed Abdel Aal       0.0            0.0            0.0               0.0
# Ali Salah               0.0            0.0            0.0              75.0
# Mohamed Moussa          0.0           62.5            7.0               3.0
# Karim Magdy             0.0            1.5           54.0              15.8
# Ahmed Morsy             0.0            0.0           12.0              48.5
# Hany Lotfy             38.0            0.0            0.0               0.0
# Ahmed Saad              0.0            0.0            0.0              22.5
# Alaa Antar              0.0            0.0            0.0              21.0
# Mahmoud Mostafa         0.0            0.0            7.0              13.0
# Ahmed Bakry             0.0            0.0            9.5               2.0
# Mohamed El-Sayed        0.0            0.0            0.0               7.5
#
# Location             Tower
# Safety Supervisor
# Mahmoud AbdelTawab    0.00
# Mohamed Abdel Aal   116.35
# Ali Salah             0.00
# Mohamed Moussa        0.00
# Karim Magdy           0.00
# Ahmed Morsy           0.00
# Hany Lotfy            0.00
# Ahmed Saad            0.00
# Alaa Antar            0.00
# Mahmoud Mostafa       0.00
# Ahmed Bakry           0.00
# Mohamed El-Sayed      0.00

# %%
plt.figure(figsize=(14, 10))

ax = result.loc[result.sum(axis=1).sort_values(ascending=False).index].plot(
    kind='barh', 
    color=MY_colors,
    width=1.5,
    edgecolor='black',
    linewidth=0.5
)

# إخفاء التسميات للقيم الصفرية
for container in ax.containers:
    labels = [f'{int(val)}' if val > 0 else '' for val in container.datavalues]
    ax.bar_label(container, labels=labels, label_type='center', padding=3, fontsize=10)

# تعديل حدود المحور لإخفاء المساحة الفارغة
plt.xlim(left=0, right=result.values.max() * 1.1)  # زيادة بنسبة 10% لأعلى قيمة

plt.title('Safety Supervisor', color="#B4056B", fontsize=16, fontweight='bold')
plt.xlabel('Total Hours', fontsize=12)
plt.ylabel('Safety Supervisor', fontsize=12)
plt.legend(title='Location', title_fontsize=12, fontsize=10)

ax.set_facecolor("#f5e1cf")
plt.grid(axis='x', alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

# %%
location_TotalHours=df.loc[df['Location'] != 'Deutsch'].groupby('Location')['Total Hours'].sum().sort_values(ascending=False)
location_TotalHours
# Out:
# Location
# Old Warehouse       241.50
# Printing Presses    217.30
# Tower               116.35
# New Warehouse        70.00
# Faggala              38.00
# Name: Total Hours, dtype: float64

# %%
ax=location_TotalHours.plot(kind='bar',color=MY_colors)
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge')
plt.title("location' Work Insurance",color="#B4056B")
plt.ylabel('Total Hours')
ax.set_facecolor("#c8eeb6")
plt.show()

# %%
df['Total Hours']=df['Total Hours'].replace({'٫':'.'})

# %%
df['Total Hours']
# Out:
# 0      3.0
# 1      3.0
# 2      5.0
# 3      1.0
# 4      5.0
#       ...
# 186    2.0
# 187    1.0
# 188    4.5
# 189    4.5
# 190    5.0
# Name: Total Hours, Length: 191, dtype: float64

# %%
df.groupby(['Safety Supervisor'])['Total Hours'].sum().sort_values(ascending=False)
# Out:
# Safety Supervisor
# Mahmoud AbdelTawab    167.00
# Mohamed Abdel Aal     116.35
# Karim Magdy            78.30
# Ali Salah              75.00
# Mohamed Moussa         72.50
# Ahmed Morsy            65.00
# Hany Lotfy             38.00
# Ahmed Saad             29.50
# Mahmoud Mostafa        24.50
# Alaa Antar             21.00
# Ahmed Bakry            11.50
# Mohamed El-Sayed        7.50
# Name: Total Hours, dtype: float64

# %%
ax=df.groupby(['Safety Supervisor'])['Total Hours'].sum().sort_values(ascending=False).plot(kind='bar',color=MY_colors)
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge')
plt.title("Contractors' Work Insurance",color="#B4056B")
plt.ylabel('Total Hours')
ax.set_facecolor("#f3bff3")
plt.show()

# %%
df.to_csv('work_permations_English2.csv')

# %%
df['Company_Name'].unique()
# Out:
# array(['Administrative Affairs', 'Al-Huda Company',
#        'Al-Amal for Installation Company', 'Engineering Sector',
#        'Orion Company', 'External Contractor', 'German Company',
#        'Schlender Company', 'One Connect Company', 'Warehouse Management',
#        'Al-Darawy Company', 'Square Company', 'Al-Bakry Company',
#        'Al-Farag Company', 'Egyptian Company', 'Atlas Company',
#        'Engineering for Air Compressors', 'Cairo Trade Company',
#        'Al-Dessouky Company', 'Follow-up and Monitoring Management',
#        'Office Max', 'Chemex Company', 'GM Company', 'KUC Company',
#        'Four Tech Company', 'Al-Karim Company', 'National Company',
#        'Globe Well Company', 'United Company', 'Alexandria Company',
#        'Al-Hady Company'], dtype=object)

# %%
df.groupby(['Company_Name'])['Total Hours'].sum()
# Out:
# Company_Name
# Administrative Affairs                 190.50
# Al-Amal for Installation Company         6.50
# Al-Bakry Company                        20.60
# Al-Darawy Company                        6.00
# Al-Dessouky Company                     43.00
# Al-Farag Company                        53.50
# Al-Hady Company                          5.00
# Al-Huda Company                        118.00
# Al-Karim Company                        13.00
# Alexandria Company                       4.50
# Atlas Company                            0.50
# Cairo Trade Company                      6.50
# Chemex Company                           2.00
# Egyptian Company                        35.00
# Engineering Sector                      39.50
# Engineering for Air Compressors          1.80
# External Contractor                      2.00
# Follow-up and Monitoring Management      4.00
# Four Tech Company                       10.00
# GM Company                              18.50
# German Company                          35.50
# Globe Well Company                       2.00
# KUC Company                              3.00
# National Company                         3.50
# Office Max                              35.25
# One Connect Company                      3.50
# Orion Company                           18.00
# Schlender Company                        6.00
# Square Company                          17.00
# United Company                           0.50
# Warehouse Management                     1.50
# Name: Total Hours, dtype: float64

# %%
result = df.groupby(['Company_Name'])['Total Hours'].sum().reset_index()
result
# Out:
#                            Company_Name  Total Hours
# 0                Administrative Affairs       190.50
# 1      Al-Amal for Installation Company         6.50
# 2                      Al-Bakry Company        20.60
# 3                     Al-Darawy Company         6.00
# 4                   Al-Dessouky Company        43.00
# 5                      Al-Farag Company        53.50
# 6                       Al-Hady Company         5.00
# 7                       Al-Huda Company       118.00
# 8                      Al-Karim Company        13.00
# 9                    Alexandria Company         4.50
# 10                        Atlas Company         0.50
# 11                  Cairo Trade Company         6.50
# 12                       Chemex Company         2.00
# 13                     Egyptian Company        35.00
# 14                   Engineering Sector        39.50
# 15      Engineering for Air Compressors         1.80
# 16                  External Contractor         2.00
# 17  Follow-up and Monitoring Management         4.00
# 18                    Four Tech Company        10.00
# 19                           GM Company        18.50
# 20                       German Company        35.50
# 21                   Globe Well Company         2.00
# 22                          KUC Company         3.00
# 23                     National Company         3.50
# 24                           Office Max        35.25
# 25                  One Connect Company         3.50
# 26                        Orion Company        18.00
# 27                    Schlender Company         6.00
# 28                       Square Company        17.00
# 29                       United Company         0.50
# 30                 Warehouse Management         1.50

# %%
company_hours=df.groupby(['Company_Name'])['Total Hours'].sum()
ax=company_hours.plot(kind='barh',color=MY_colors)
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge')
ax.set_facecolor("#ecb3c4ee")
plt.show()
